# %% [markdown]
# Assignment 2:
#
# First lets create two table s of Employees and Department

# %%
# %sql
-- Create departments table
CREATE OR REPLACE TABLE departments (
    dept_id INT,
    dept_name STRING
);

# %%
# %sql
-- Create employees table
CREATE OR REPLACE TABLE employees (
    emp_id INT,
    name STRING,
    salary INT,
    dept_id INT,
    hire_date DATE
);

# %%
# %sql
-- Insert data into departments
INSERT INTO departments VALUES
    (10, 'Engineering'),
    (20, 'Sales'),
    (30, 'Human Resources'),
    (40, 'Marketing'),
    (50, 'Finance'),
    (60, 'Research');
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>6</td><td>6</td></tr></tbody></table></div>

# %%
# %sql
INSERT INTO employees VALUES
    (101, 'Aarav Shrestha',   85000, 10,   DATE '2021-03-15'),
    (102, 'Priya Maharjan',   92000, 10,   DATE '2021-07-22'),
    (103, 'Rohan Adhikari',   78000, 10,   DATE '2022-01-10'),
    (104, 'Sneha Karki',      65000, 20,   DATE '2022-11-05'),
    (105, 'Bikram Thapa',     72000, 20,   DATE '2023-09-18'),
    (106, 'Ananya Gurung',    58000, 30,   DATE '2023-02-14'),
    (107, 'Karan Pradhan',    61000, 30,   DATE '2023-06-30'),
    (108, 'Diya Tamang',      69000, 40,   DATE '2024-12-01'),
    (109, 'Arjun KC',         74000, 40,   DATE '2024-08-25'),
    (110, 'Meera Bhattarai',  88000, 50,   DATE '2021-04-12'),
    (111, 'Rahul Ghimire',    95000, 50,   DATE '2022-10-08'),
    (112, 'Ishita Basnet',    71000, 10,   DATE '2025-05-20'),
    (113, 'Siddhartha Rai',   67000, 20,   DATE '2025-01-15'),
    (114, 'Nisha Lamichhane', 82000, NULL,   DATE '2024-03-07'),
    (115, 'Aditya Magar',     90000, 50,   DATE '2025-02-28');
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>15</td><td>15</td></tr></tbody></table></div>

# %%
# %sql
--Question 1 - Departments with more than 3 employees

SELECT d.dept_id,
       d.dept_name,
       COUNT(e.emp_id) AS employee_count
FROM departments d
JOIN employees e ON d.dept_id = e.dept_id
GROUP BY d.dept_id, d.dept_name
HAVING COUNT(e.emp_id) > 3;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dept_id</th><th>dept_name</th><th>employee_count</th></tr></thead><tbody><tr><td>10</td><td>Engineering</td><td>4</td></tr></tbody></table></div>

# %%
# %sql
--Question 2 - Find departments with no employees(joins)
SELECT d.dept_name
FROM departments d
LEFT JOIN employees e ON d.dept_id = e.dept_id
WHERE e.emp_id IS NULL;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dept_name</th></tr></thead><tbody><tr><td>Research</td></tr></tbody></table></div>

# %%
# %sql
--Question 3: Find employees without department (JOIN)
SELECT e.name
FROM employees e
LEFT JOIN departments d ON e.dept_id = d.dept_id
WHERE d.dept_id IS NULL;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th></tr></thead><tbody><tr><td>Nisha Lamichhane</td></tr></tbody></table></div>

# %%
# %sql
--Question 4 - Find second highest salary
SELECT MAX(salary) AS second_highest_salary
FROM employees
WHERE salary < (SELECT MAX(salary) FROM employees);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>second_highest_salary</th></tr></thead><tbody><tr><td>92000</td></tr></tbody></table></div>

# %%
# %sql
--Question 4 - Find second highest salary(Using WIndow Funtion)
SELECT name, salary
FROM (
    SELECT name,
           salary,
           DENSE_RANK() OVER (ORDER BY salary DESC) AS rnk
    FROM employees
) ranked
WHERE rnk = 2;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>salary</th></tr></thead><tbody><tr><td>Priya Maharjan</td><td>92000</td></tr></tbody></table></div>

# %%
# %sql
--Question 5 - Count employees hired per year
SELECT YEAR(hire_date) AS hire_year,
       COUNT(*) AS employee_count
FROM employees
GROUP BY YEAR(hire_date)
ORDER BY hire_year;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>hire_year</th><th>employee_count</th></tr></thead><tbody><tr><td>2021</td><td>3</td></tr><tr><td>2022</td><td>3</td></tr><tr><td>2023</td><td>3</td></tr><tr><td>2024</td><td>3</td></tr><tr><td>2025</td><td>3</td></tr></tbody></table></div>

# %%
# %sql
SELECT emp_id,
       name,
       hire_date,
       salary,
       SUM(salary) OVER (ORDER BY hire_date, emp_id) AS running_total
FROM employees;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
